# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## IMPORTING DEPENDENCIES

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa, librosa.display

import tensorflow as tf 
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## TRAIN, TEST, VALIDATION DATA RETRIEVAL

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, GRU, Input, Conv1D, MaxPooling1D, LSTM
from sklearn.metrics import confusion_matrix, classification_report

# %%
X_train = np.load('/content/gdrive/MyDrive/data/Augmented1/X_train.npy')
y_train = np.load('/content/gdrive/MyDrive/data/Augmented1/y_train.npy')
X_test = np.load('/content/gdrive/MyDrive/data/Augmented1/X_test.npy')
y_test = np.load('/content/gdrive/MyDrive/data/Augmented1/y_test.npy')
X_val = np.load('/content/gdrive/MyDrive/data/Augmented1/X_val.npy')
y_val = np.load('/content/gdrive/MyDrive/data/Augmented1/y_val.npy')

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (16893, 98) (16893, 2)
# (2109, 98) (2109, 2)
# (2088, 98) (2088, 2)

# %% [markdown]
# ## NEURAL NETWORK MODEL

# %%
model = Sequential()
model.add(Conv1D(32, 5, activation='relu', input_shape=(98,1)))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 5, activation='relu'))
model.add(MaxPooling1D(2))
model.add(GRU(128, return_sequences=True))
model.add(LSTM(128))
model.add(tf.keras.layers.Dense(32))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Activation('relu'))
model.add(Dense(2, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 94, 32)            192
#
#  max_pooling1d (MaxPooling1D  (None, 47, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 43, 64)            10304
#
#  max_pooling1d_1 (MaxPooling  (None, 21, 64)           0
#  1D)
#
#  gru (GRU)                   (None, 21, 128)           74496
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 32)                4128
#
#  dropout (Dropout)           (None, 32)                0
#
#  activation (Activation)     (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 220,770
# Trainable params: 220,770
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
optimizer=tf.keras.optimizers.Adam(amsgrad=True, name='Adam')

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer = optimizer,
    metrics=['accuracy']
)

# %%
print("Model Score: \n")
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 120, shuffle = False)
# Out:
# Model Score:
#
# Epoch 1/120
# 528/528 [==============================] - 21s 11ms/step - loss: 0.6426 - accuracy: 0.6087 - val_loss: 0.4121 - val_accuracy: 0.8218
# Epoch 2/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2629 - accuracy: 0.9036 - val_loss: 0.2390 - val_accuracy: 0.9267
# Epoch 3/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.1807 - accuracy: 0.9362 - val_loss: 0.2049 - val_accuracy: 0.9325
# Epoch 4/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.1540 - accuracy: 0.9465 - val_loss: 0.2024 - val_accuracy: 0.9368
# Epoch 5/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1447 - accuracy: 0.9511 - val_loss: 0.1882 - val_accuracy: 0.9411
# Epoch 6/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.1299 - accuracy: 0.9562 - val_loss: 0.1785 - val_accuracy: 0.9449
# Epoch 7/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.1216 - accuracy: 0.9592 - val_loss: 0.1515 - val_accuracy: 0.9430
# Epoch 8/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1108 - accuracy: 0.9612 - val_loss: 0.1429 - val_accuracy: 0.9535
# Epoch 9/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.1023 - accuracy: 0.9643 - val_loss: 0.1390 - val_accuracy: 0.9507
# Epoch 10/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0881 - accuracy: 0.9702 - val_loss: 0.1437 - val_accuracy: 0.9535
# Epoch 11/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0867 - accuracy: 0.9700 - val_loss: 0.1296 - val_accuracy: 0.9574
# Epoch 12/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0789 - accuracy: 0.9722 - val_loss: 0.1425 - val_accuracy: 0.9569
# Epoch 13/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0718 - accuracy: 0.9747 - val_loss: 0.1281 - val_accuracy: 0.9593
# Epoch 14/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0610 - accuracy: 0.9788 - val_loss: 0.1206 - val_accuracy: 0.9617
# Epoch 15/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0591 - accuracy: 0.9790 - val_loss: 0.1468 - val_accuracy: 0.9574
# Epoch 16/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0560 - accuracy: 0.9796 - val_loss: 0.1293 - val_accuracy: 0.9684
# Epoch 17/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0447 - accuracy: 0.9844 - val_loss: 0.1427 - val_accuracy: 0.9679
# Epoch 18/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0416 - accuracy: 0.9856 - val_loss: 0.1207 - val_accuracy: 0.9708
# Epoch 19/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0459 - accuracy: 0.9837 - val_loss: 0.1198 - val_accuracy: 0.9713
# Epoch 20/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0335 - accuracy: 0.9876 - val_loss: 0.1316 - val_accuracy: 0.9703
# Epoch 21/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0308 - accuracy: 0.9904 - val_loss: 0.1226 - val_accuracy: 0.9717
# Epoch 22/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0293 - accuracy: 0.9898 - val_loss: 0.1508 - val_accuracy: 0.9655
# Epoch 23/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0273 - accuracy: 0.9905 - val_loss: 0.1489 - val_accuracy: 0.9746
# Epoch 24/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0282 - accuracy: 0.9906 - val_loss: 0.0995 - val_accuracy: 0.9751
# Epoch 25/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.1138 - val_accuracy: 0.9727
# Epoch 26/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0330 - accuracy: 0.9886 - val_loss: 0.1169 - val_accuracy: 0.9674
# Epoch 27/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.1025 - val_accuracy: 0.9756
# Epoch 28/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.1247 - val_accuracy: 0.9756
# Epoch 29/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0218 - accuracy: 0.9933 - val_loss: 0.1211 - val_accuracy: 0.9741
# Epoch 30/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.2111 - val_accuracy: 0.9646
# Epoch 31/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.1183 - val_accuracy: 0.9775
# Epoch 32/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.1345 - val_accuracy: 0.9761
# Epoch 33/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0147 - accuracy: 0.9953 - val_loss: 0.1163 - val_accuracy: 0.9732
# Epoch 34/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.1337 - val_accuracy: 0.9713
# Epoch 35/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.1200 - val_accuracy: 0.9732
# Epoch 36/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.1396 - val_accuracy: 0.9717
# Epoch 37/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.1382 - val_accuracy: 0.9746
# Epoch 38/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.1549 - val_accuracy: 0.9746
# Epoch 39/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.1611 - val_accuracy: 0.9765
# Epoch 40/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.1597 - val_accuracy: 0.9756
# Epoch 41/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.2098 - val_accuracy: 0.9741
# Epoch 42/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.2064 - val_accuracy: 0.9761
# Epoch 43/120
# 528/528 [==============================] - 4s 8ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1877 - val_accuracy: 0.9765
# Epoch 44/120
# 528/528 [==============================] - 5s 9ms/step - loss: 9.4308e-04 - accuracy: 0.9998 - val_loss: 0.1918 - val_accuracy: 0.9765
# Epoch 45/120
# 528/528 [==============================] - 5s 10ms/step - loss: 4.3148e-04 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9761
# Epoch 46/120
# 528/528 [==============================] - 4s 8ms/step - loss: 4.0140e-04 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9770
# Epoch 47/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.7437e-04 - accuracy: 0.9999 - val_loss: 0.2134 - val_accuracy: 0.9761
# Epoch 48/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.2512e-04 - accuracy: 1.0000 - val_loss: 0.2183 - val_accuracy: 0.9765
# Epoch 49/120
# 528/528 [==============================] - 4s 8ms/step - loss: 2.3495e-04 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9761
# Epoch 50/120
# 528/528 [==============================] - 5s 10ms/step - loss: 1.4067e-04 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9761
# Epoch 51/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.7369e-04 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9756
# Epoch 52/120
# 528/528 [==============================] - 4s 8ms/step - loss: 1.7691e-04 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9756
# Epoch 53/120
# 528/528 [==============================] - 5s 10ms/step - loss: 1.9597e-04 - accuracy: 1.0000 - val_loss: 0.2333 - val_accuracy: 0.9765
# Epoch 54/120
# 528/528 [==============================] - 4s 8ms/step - loss: 1.1063e-04 - accuracy: 1.0000 - val_loss: 0.2344 - val_accuracy: 0.9765
# Epoch 55/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.5382e-04 - accuracy: 0.9999 - val_loss: 0.2360 - val_accuracy: 0.9765
# Epoch 56/120
# 528/528 [==============================] - 5s 10ms/step - loss: 1.7052e-04 - accuracy: 1.0000 - val_loss: 0.2396 - val_accuracy: 0.9770
# Epoch 57/120
# 528/528 [==============================] - 5s 10ms/step - loss: 1.3138e-04 - accuracy: 0.9999 - val_loss: 0.2410 - val_accuracy: 0.9775
# Epoch 58/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.2635e-04 - accuracy: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9765
# Epoch 59/120
# 528/528 [==============================] - 5s 9ms/step - loss: 8.2630e-05 - accuracy: 1.0000 - val_loss: 0.2468 - val_accuracy: 0.9770
# Epoch 60/120
# 528/528 [==============================] - 4s 8ms/step - loss: 9.5094e-05 - accuracy: 1.0000 - val_loss: 0.2450 - val_accuracy: 0.9780
# Epoch 61/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.5386e-04 - accuracy: 0.9999 - val_loss: 0.2496 - val_accuracy: 0.9775
# Epoch 62/120
# 528/528 [==============================] - 5s 9ms/step - loss: 9.4558e-05 - accuracy: 1.0000 - val_loss: 0.2489 - val_accuracy: 0.9775
# Epoch 63/120
# 528/528 [==============================] - 4s 8ms/step - loss: 1.3337e-04 - accuracy: 0.9999 - val_loss: 0.2495 - val_accuracy: 0.9775
# Epoch 64/120
# 528/528 [==============================] - 6s 10ms/step - loss: 7.8638e-05 - accuracy: 1.0000 - val_loss: 0.2526 - val_accuracy: 0.9775
# Epoch 65/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.5319e-04 - accuracy: 1.0000 - val_loss: 0.2528 - val_accuracy: 0.9775
# Epoch 66/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.5471e-04 - accuracy: 0.9999 - val_loss: 0.2507 - val_accuracy: 0.9780
# Epoch 67/120
# 528/528 [==============================] - 5s 10ms/step - loss: 6.1869e-05 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9780
# Epoch 68/120
# 528/528 [==============================] - 4s 8ms/step - loss: 5.5862e-05 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9780
# Epoch 69/120
# 528/528 [==============================] - 4s 8ms/step - loss: 5.8781e-05 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9775
# Epoch 70/120
# 528/528 [==============================] - 5s 10ms/step - loss: 9.2337e-05 - accuracy: 1.0000 - val_loss: 0.2594 - val_accuracy: 0.9780
# Epoch 71/120
# 528/528 [==============================] - 4s 8ms/step - loss: 8.2781e-05 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9775
# Epoch 72/120
# 528/528 [==============================] - 5s 10ms/step - loss: 6.2842e-05 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9775
# Epoch 73/120
# 528/528 [==============================] - 5s 9ms/step - loss: 6.2031e-05 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9775
# Epoch 74/120
# 528/528 [==============================] - 5s 9ms/step - loss: 6.4078e-05 - accuracy: 1.0000 - val_loss: 0.2666 - val_accuracy: 0.9775
# Epoch 75/120
# 528/528 [==============================] - 5s 10ms/step - loss: 5.0845e-05 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9775
# Epoch 76/120
# 528/528 [==============================] - 5s 9ms/step - loss: 7.7077e-05 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9770
# Epoch 77/120
# 528/528 [==============================] - 4s 8ms/step - loss: 4.7785e-05 - accuracy: 1.0000 - val_loss: 0.2685 - val_accuracy: 0.9770
# Epoch 78/120
# 528/528 [==============================] - 5s 10ms/step - loss: 7.2843e-05 - accuracy: 1.0000 - val_loss: 0.2703 - val_accuracy: 0.9770
# Epoch 79/120
# 528/528 [==============================] - 4s 9ms/step - loss: 5.1961e-05 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.9770
# Epoch 80/120
# 528/528 [==============================] - 5s 9ms/step - loss: 7.8575e-05 - accuracy: 1.0000 - val_loss: 0.2737 - val_accuracy: 0.9770
# Epoch 81/120
# 528/528 [==============================] - 5s 10ms/step - loss: 8.1036e-05 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9765
# Epoch 82/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.9775e-05 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.9765
# Epoch 83/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.7265e-05 - accuracy: 1.0000 - val_loss: 0.2815 - val_accuracy: 0.9775
# Epoch 84/120
# 528/528 [==============================] - 5s 10ms/step - loss: 4.9174e-05 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9775
# Epoch 85/120
# 528/528 [==============================] - 4s 8ms/step - loss: 5.6740e-05 - accuracy: 1.0000 - val_loss: 0.2839 - val_accuracy: 0.9770
# Epoch 86/120
# 528/528 [==============================] - 5s 10ms/step - loss: 1.2119e-04 - accuracy: 0.9999 - val_loss: 0.2863 - val_accuracy: 0.9770
# Epoch 87/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.9242e-05 - accuracy: 1.0000 - val_loss: 0.2867 - val_accuracy: 0.9770
# Epoch 88/120
# 528/528 [==============================] - 5s 9ms/step - loss: 7.7195e-05 - accuracy: 1.0000 - val_loss: 0.2890 - val_accuracy: 0.9770
# Epoch 89/120
# 528/528 [==============================] - 5s 10ms/step - loss: 3.7089e-05 - accuracy: 1.0000 - val_loss: 0.2866 - val_accuracy: 0.9770
# Epoch 90/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.8663e-05 - accuracy: 1.0000 - val_loss: 0.2841 - val_accuracy: 0.9775
# Epoch 91/120
# 528/528 [==============================] - 5s 9ms/step - loss: 6.1790e-05 - accuracy: 1.0000 - val_loss: 0.2853 - val_accuracy: 0.9770
# Epoch 92/120
# 528/528 [==============================] - 5s 10ms/step - loss: 5.4409e-05 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9770
# Epoch 93/120
# 528/528 [==============================] - 4s 8ms/step - loss: 4.3191e-05 - accuracy: 1.0000 - val_loss: 0.2874 - val_accuracy: 0.9770
# Epoch 94/120
# 528/528 [==============================] - 4s 8ms/step - loss: 6.7661e-05 - accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 0.9770
# Epoch 95/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.2864e-05 - accuracy: 1.0000 - val_loss: 0.2882 - val_accuracy: 0.9770
# Epoch 96/120
# 528/528 [==============================] - 5s 9ms/step - loss: 5.3921e-05 - accuracy: 1.0000 - val_loss: 0.2895 - val_accuracy: 0.9770
# Epoch 97/120
# 528/528 [==============================] - 5s 9ms/step - loss: 7.1232e-05 - accuracy: 0.9999 - val_loss: 0.2899 - val_accuracy: 0.9770
# Epoch 98/120
# 528/528 [==============================] - 5s 10ms/step - loss: 7.0646e-05 - accuracy: 0.9999 - val_loss: 0.2889 - val_accuracy: 0.9770
# Epoch 99/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.3530e-05 - accuracy: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.9770
# Epoch 100/120
# 528/528 [==============================] - 5s 10ms/step - loss: 3.4771e-05 - accuracy: 1.0000 - val_loss: 0.2911 - val_accuracy: 0.9770
# Epoch 101/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.2429e-05 - accuracy: 1.0000 - val_loss: 0.2912 - val_accuracy: 0.9770
# Epoch 102/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.8841e-05 - accuracy: 1.0000 - val_loss: 0.2892 - val_accuracy: 0.9770
# Epoch 103/120
# 528/528 [==============================] - 6s 11ms/step - loss: 7.1128e-05 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.9770
# Epoch 104/120
# 528/528 [==============================] - 4s 9ms/step - loss: 2.2570e-05 - accuracy: 1.0000 - val_loss: 0.2915 - val_accuracy: 0.9770
# Epoch 105/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.4531e-05 - accuracy: 1.0000 - val_loss: 0.2944 - val_accuracy: 0.9770
# Epoch 106/120
# 528/528 [==============================] - 5s 10ms/step - loss: 7.2897e-05 - accuracy: 0.9999 - val_loss: 0.2938 - val_accuracy: 0.9770
# Epoch 107/120
# 528/528 [==============================] - 4s 8ms/step - loss: 8.0564e-05 - accuracy: 0.9999 - val_loss: 0.2922 - val_accuracy: 0.9770
# Epoch 108/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.8511e-05 - accuracy: 1.0000 - val_loss: 0.2953 - val_accuracy: 0.9770
# Epoch 109/120
# 528/528 [==============================] - 5s 10ms/step - loss: 4.6493e-05 - accuracy: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.9770
# Epoch 110/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.8141e-05 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.9770
# Epoch 111/120
# 528/528 [==============================] - 5s 10ms/step - loss: 6.1323e-05 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9770
# Epoch 112/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.2015e-05 - accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.9770
# Epoch 113/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.1871e-05 - accuracy: 1.0000 - val_loss: 0.2938 - val_accuracy: 0.9770
# Epoch 114/120
# 528/528 [==============================] - 5s 10ms/step - loss: 4.0656e-05 - accuracy: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.9770
# Epoch 115/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.5552e-05 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9770
# Epoch 116/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.3935e-05 - accuracy: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.9770
# Epoch 117/120
# 528/528 [==============================] - 6s 11ms/step - loss: 1.0966e-04 - accuracy: 0.9999 - val_loss: 0.3009 - val_accuracy: 0.9770
# Epoch 118/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.1642e-04 - accuracy: 0.9999 - val_loss: 0.3029 - val_accuracy: 0.9770
# Epoch 119/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.6830e-05 - accuracy: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9770
# Epoch 120/120
# 528/528 [==============================] - 5s 10ms/step - loss: 4.1035e-05 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9770

# %%
model.save("/content/gdrive/MyDrive/Models/CRNN_GRULSTM_Standalone_WithDense.h5")
score = model.evaluate(X_test, y_test)
print(score)
# Out:
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1593 - accuracy: 0.9853
# [0.15926708281040192, 0.9853010773658752]

# %% [markdown]
# ## METRICS

# %%
pip install plot_keras_history
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plot_keras_history
#   Downloading plot_keras_history-1.1.38.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (3.5.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.7.3)
# Collecting support_developer>=1.0.2
#   Downloading support_developer-1.0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sanitize_ml_labels>=1.0.48
#   Downloading sanitize_ml_labels-1.0.50.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 KB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting compress_json
#   Downloading compress_json-1.0.8.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (7.1.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->plot_keras_history) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.15.0)
# Building wheels for collected packages: plot_keras_history, sanitize_ml_labels, support_developer, compress_json
#   Building wheel for plot_keras_history (setup.py) ... done
#   Created wheel for plot_keras_history: filename=plot_keras_history-1.1.38-py3-none-any.whl size=9472 sha256=50fcd38b93bff9cf6de1bd5f81e220c29d8717dda60d4e11511e78ce9c478a09
#   Stored in directory: /root/.cache/pip/wheels/97/a5/76/35ae3e15da1ce4530de8591b0bcd7716f6d6752a4808f01c04
#   Building wheel for sanitize_ml_labels (setup.py) ... done
#   Created wheel for sanitize_ml_labels: filename=sanitize_ml_labels-1.0.50-py3-none-any.whl size=320514 sha256=169046727a8597b8c1e69c12e5d5013ccf2cc0f770529908fe4e03310cc92fdc
#   Stored in directory: /root/.cache/pip/wheels/a3/5f/ba/ddd191edb6c749a63cffabd28714d5600b5b58014daf7434a8
#   Building wheel for support_developer (setup.py) ... done
#   Created wheel for support_developer: filename=support_developer-1.0.5-py3-none-any.whl size=5650 sha256=a97d4dcfc9935ab4c3e64ceb4867f08db5127ba8532e393cd9f2eb515e271747
#   Stored in directory: /root/.cache/pip/wheels/11/5e/63/51e84640e77a7dc5f1e5f5eb597e8f1bc730a2818ee5c3fc03
#   Building wheel for compress_json (setup.py) ... done
#   Created wheel for compress_json: filename=compress_json-1.0.8-py3-none-any.whl size=4733 sha256=cc4e6239299021237b9aaee8c96a4ed11be62e84705c4493cac691a5b1ba3336
#   Stored in directory: /root/.cache/pip/wheels/fe/36/4b/69aaa23fc0ea813dc1f8cca3372bff314abed354cac20a1cb9
# Successfully built plot_keras_history sanitize_ml_labels support_developer compress_json
# Installing collected packages: support_developer, compress_json, sanitize_ml_labels, plot_keras_history
# Successfully installed compress_json-1.0.8 plot_keras_history-1.1.38 sanitize_ml_labels-1.0.50 support_developer-1.0.5

# %%
from plot_keras_history import show_history, plot_history
plot_history(history)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>,
#         <AxesSubplot:title={'center':'Accuracy'}, xlabel='Epochs', ylabel='Accuracy'>],
#        dtype=object))

# %%
import matplotlib.pyplot as plt
import itertools
import numpy as np

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
print("Model Classification Report: \n")
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
print(classification_report(np.argmax(y_test, axis=1), y_pred))
plot_confusion_matrix(cm, classes=["Does not have Wake Word", "Has Wake Word"])
# Out:
# Model Classification Report:
#
# 66/66 [==============================] - 2s 22ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      1049
#            1       0.98      0.99      0.99      1060
#
#     accuracy                           0.99      2109
#    macro avg       0.99      0.99      0.99      2109
# weighted avg       0.99      0.99      0.99      2109
#
# Confusion matrix, without normalization
# [[1030   19]
#  [  12 1048]]

# %% [markdown]
# ##PREDICTION & LATENCY

# %%
pip install spafe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spafe
#   Downloading spafe-0.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.7.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from spafe) (4.5.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.22.4)
# Installing collected packages: spafe
# Successfully installed spafe-0.3.1

# %%
import spafe
from spafe.features.lfcc import lfcc
import pywt

# %%
def predict(audio):
  audio_data, sr = librosa.load(audio)

  wavelet = 'db4'
  level = 4
  coeffs = pywt.wavedec(audio_data, wavelet, level=level)
  threshold = np.median(np.abs(coeffs[-level])) / 0.6745
  for i in range(1, len(coeffs)):
    coeffs[i] = pywt.threshold(coeffs[i], threshold)
  denoised_audio = pywt.waverec(coeffs, wavelet)

  lfccs  = lfcc(denoised_audio, fs = sr, num_ceps=13)
  lfccs_processed = np.mean(lfccs.T, axis=0) # some pre-processing
  lfccs_new = np.expand_dims(np.asarray(lfccs_processed), axis=0)
  predictions = model.predict(lfccs_new)
  return predictions

# %%
audio_for_pred = "/content/gdrive/MyDrive/Marvin/marvin (170).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 48ms/step
# [[1. 0.]]

# %%
audio_for_pred = "/content/gdrive/MyDrive/False/yes (824).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# [[1. 0.]]
