# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## IMPORTING DEPENDENCIES

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa, librosa.display

import tensorflow as tf 
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## TRAIN, TEST, VALIDATION DATA RETRIEVAL

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, GRU, Input, Conv1D, MaxPooling1D, LSTM
from sklearn.metrics import confusion_matrix, classification_report

# %%
X_train = np.load('/content/gdrive/MyDrive/data/Augmented1/X_train.npy')
y_train = np.load('/content/gdrive/MyDrive/data/Augmented1/y_train.npy')
X_test = np.load('/content/gdrive/MyDrive/data/Augmented1/X_test.npy')
y_test = np.load('/content/gdrive/MyDrive/data/Augmented1/y_test.npy')
X_val = np.load('/content/gdrive/MyDrive/data/Augmented1/X_val.npy')
y_val = np.load('/content/gdrive/MyDrive/data/Augmented1/y_val.npy')

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (16893, 98) (16893, 2)
# (2109, 98) (2109, 2)
# (2088, 98) (2088, 2)

# %% [markdown]
# ## NEURAL NETWORK MODEL

# %%
model = Sequential()
model.add(Conv1D(32, 5, activation='relu', input_shape=(98,1)))
model.add(MaxPooling1D(2))
model.add(Conv1D(64, 5, activation='relu'))
model.add(MaxPooling1D(2))
model.add(LSTM(128, return_sequences=True))
model.add(GRU(128))
model.add(Dense(2, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 94, 32)            192
#
#  max_pooling1d (MaxPooling1D  (None, 47, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 43, 64)            10304
#
#  max_pooling1d_1 (MaxPooling  (None, 21, 64)           0
#  1D)
#
#  lstm (LSTM)                 (None, 21, 128)           98816
#
#  gru (GRU)                   (None, 128)               99072
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 208,642
# Trainable params: 208,642
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
optimizer=tf.keras.optimizers.Adam(amsgrad=True, name='Adam')

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer = optimizer,
    metrics=['accuracy']
)

# %%
print("Model Score: \n")
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 120, shuffle = False)
# Out:
# Model Score:
#
# Epoch 1/120
# 528/528 [==============================] - 50s 85ms/step - loss: 0.6155 - accuracy: 0.6461 - val_loss: 0.4774 - val_accuracy: 0.7706
# Epoch 2/120
# 528/528 [==============================] - 51s 97ms/step - loss: 0.2466 - accuracy: 0.9046 - val_loss: 0.2172 - val_accuracy: 0.9229
# Epoch 3/120
# 528/528 [==============================] - 43s 81ms/step - loss: 0.1662 - accuracy: 0.9365 - val_loss: 0.2303 - val_accuracy: 0.9157
# Epoch 4/120
# 528/528 [==============================] - 42s 80ms/step - loss: 0.1461 - accuracy: 0.9467 - val_loss: 0.2260 - val_accuracy: 0.9215
# Epoch 5/120
# 528/528 [==============================] - 44s 84ms/step - loss: 0.1322 - accuracy: 0.9516 - val_loss: 0.1857 - val_accuracy: 0.9344
# Epoch 6/120
# 528/528 [==============================] - 43s 81ms/step - loss: 0.1228 - accuracy: 0.9552 - val_loss: 0.1807 - val_accuracy: 0.9377
# Epoch 7/120
# 528/528 [==============================] - 43s 81ms/step - loss: 0.1148 - accuracy: 0.9572 - val_loss: 0.1795 - val_accuracy: 0.9344
# Epoch 8/120
# 528/528 [==============================] - 43s 81ms/step - loss: 0.1069 - accuracy: 0.9596 - val_loss: 0.1618 - val_accuracy: 0.9435
# Epoch 9/120
# 528/528 [==============================] - 45s 84ms/step - loss: 0.0983 - accuracy: 0.9638 - val_loss: 0.1610 - val_accuracy: 0.9444
# Epoch 10/120
# 528/528 [==============================] - 46s 86ms/step - loss: 0.0928 - accuracy: 0.9664 - val_loss: 0.1391 - val_accuracy: 0.9545
# Epoch 11/120
# 528/528 [==============================] - 43s 82ms/step - loss: 0.0873 - accuracy: 0.9696 - val_loss: 0.1322 - val_accuracy: 0.9516
# Epoch 12/120
# 528/528 [==============================] - 44s 82ms/step - loss: 0.0778 - accuracy: 0.9712 - val_loss: 0.1477 - val_accuracy: 0.9502
# Epoch 13/120
# 528/528 [==============================] - 44s 84ms/step - loss: 0.0709 - accuracy: 0.9757 - val_loss: 0.1395 - val_accuracy: 0.9535
# Epoch 14/120
# 528/528 [==============================] - 46s 88ms/step - loss: 0.0707 - accuracy: 0.9747 - val_loss: 0.1190 - val_accuracy: 0.9598
# Epoch 15/120
# 528/528 [==============================] - 44s 82ms/step - loss: 0.0637 - accuracy: 0.9773 - val_loss: 0.1192 - val_accuracy: 0.9602
# Epoch 16/120
# 528/528 [==============================] - 43s 82ms/step - loss: 0.0521 - accuracy: 0.9821 - val_loss: 0.1122 - val_accuracy: 0.9636
# Epoch 17/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0525 - accuracy: 0.9808 - val_loss: 0.1208 - val_accuracy: 0.9626
# Epoch 18/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0508 - accuracy: 0.9823 - val_loss: 0.1018 - val_accuracy: 0.9679
# Epoch 19/120
# 528/528 [==============================] - 45s 86ms/step - loss: 0.0455 - accuracy: 0.9842 - val_loss: 0.1148 - val_accuracy: 0.9641
# Epoch 20/120
# 528/528 [==============================] - 44s 82ms/step - loss: 0.0441 - accuracy: 0.9839 - val_loss: 0.1284 - val_accuracy: 0.9655
# Epoch 21/120
# 528/528 [==============================] - 43s 82ms/step - loss: 0.0410 - accuracy: 0.9864 - val_loss: 0.1350 - val_accuracy: 0.9622
# Epoch 22/120
# 528/528 [==============================] - 45s 86ms/step - loss: 0.0315 - accuracy: 0.9890 - val_loss: 0.1423 - val_accuracy: 0.9650
# Epoch 23/120
# 528/528 [==============================] - 47s 88ms/step - loss: 0.0334 - accuracy: 0.9883 - val_loss: 0.1305 - val_accuracy: 0.9612
# Epoch 24/120
# 528/528 [==============================] - 46s 88ms/step - loss: 0.0266 - accuracy: 0.9901 - val_loss: 0.1271 - val_accuracy: 0.9650
# Epoch 25/120
# 528/528 [==============================] - 46s 86ms/step - loss: 0.0268 - accuracy: 0.9906 - val_loss: 0.1454 - val_accuracy: 0.9655
# Epoch 26/120
# 528/528 [==============================] - 50s 95ms/step - loss: 0.0220 - accuracy: 0.9918 - val_loss: 0.1503 - val_accuracy: 0.9703
# Epoch 27/120
# 528/528 [==============================] - 48s 91ms/step - loss: 0.0237 - accuracy: 0.9913 - val_loss: 0.1567 - val_accuracy: 0.9598
# Epoch 28/120
# 528/528 [==============================] - 50s 95ms/step - loss: 0.0333 - accuracy: 0.9886 - val_loss: 0.1271 - val_accuracy: 0.9684
# Epoch 29/120
# 528/528 [==============================] - 47s 90ms/step - loss: 0.0219 - accuracy: 0.9925 - val_loss: 0.1371 - val_accuracy: 0.9698
# Epoch 30/120
# 528/528 [==============================] - 46s 88ms/step - loss: 0.0195 - accuracy: 0.9934 - val_loss: 0.1649 - val_accuracy: 0.9650
# Epoch 31/120
# 528/528 [==============================] - 48s 91ms/step - loss: 0.0160 - accuracy: 0.9952 - val_loss: 0.1536 - val_accuracy: 0.9646
# Epoch 32/120
# 528/528 [==============================] - 49s 92ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.1420 - val_accuracy: 0.9737
# Epoch 33/120
# 528/528 [==============================] - 47s 88ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.1472 - val_accuracy: 0.9622
# Epoch 34/120
# 528/528 [==============================] - 49s 92ms/step - loss: 0.0167 - accuracy: 0.9943 - val_loss: 0.1763 - val_accuracy: 0.9650
# Epoch 35/120
# 528/528 [==============================] - 47s 89ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.1428 - val_accuracy: 0.9708
# Epoch 36/120
# 528/528 [==============================] - 47s 90ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.1446 - val_accuracy: 0.9722
# Epoch 37/120
# 528/528 [==============================] - 50s 94ms/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.1435 - val_accuracy: 0.9756
# Epoch 38/120
# 528/528 [==============================] - 46s 87ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.1404 - val_accuracy: 0.9679
# Epoch 39/120
# 528/528 [==============================] - 46s 87ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 0.1387 - val_accuracy: 0.9708
# Epoch 40/120
# 528/528 [==============================] - 47s 88ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.1371 - val_accuracy: 0.9770
# Epoch 41/120
# 528/528 [==============================] - 48s 90ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.1325 - val_accuracy: 0.9741
# Epoch 42/120
# 528/528 [==============================] - 45s 84ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.1250 - val_accuracy: 0.9761
# Epoch 43/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.1532 - val_accuracy: 0.9741
# Epoch 44/120
# 528/528 [==============================] - 45s 84ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1812 - val_accuracy: 0.9679
# Epoch 45/120
# 528/528 [==============================] - 45s 85ms/step - loss: 0.0261 - accuracy: 0.9924 - val_loss: 0.1297 - val_accuracy: 0.9737
# Epoch 46/120
# 528/528 [==============================] - 46s 88ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.1511 - val_accuracy: 0.9741
# Epoch 47/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.1455 - val_accuracy: 0.9722
# Epoch 48/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.1294 - val_accuracy: 0.9741
# Epoch 49/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.1438 - val_accuracy: 0.9751
# Epoch 50/120
# 528/528 [==============================] - 44s 83ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.1422 - val_accuracy: 0.9737
# Epoch 51/120
# 528/528 [==============================] - 48s 90ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1514 - val_accuracy: 0.9765
# Epoch 52/120
# 528/528 [==============================] - 44s 83ms/step - loss: 7.2316e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9756
# Epoch 53/120
# 528/528 [==============================] - 44s 83ms/step - loss: 3.1418e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9765
# Epoch 54/120
# 528/528 [==============================] - 44s 84ms/step - loss: 2.2049e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9765
# Epoch 55/120
# 528/528 [==============================] - 47s 89ms/step - loss: 1.6976e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9770
# Epoch 111/120
# 528/528 [==============================] - 46s 88ms/step - loss: 2.1400e-05 - accuracy: 1.0000 - val_loss: 0.1755 - val_accuracy: 0.9775
# Epoch 112/120
# 528/528 [==============================] - 46s 88ms/step - loss: 2.1069e-05 - accuracy: 1.0000 - val_loss: 0.1757 - val_accuracy: 0.9775
# Epoch 113/120
# 528/528 [==============================] - 45s 85ms/step - loss: 2.0748e-05 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.9775
# Epoch 114/120
# 528/528 [==============================] - 47s 89ms/step - loss: 2.0437e-05 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9775
# Epoch 115/120
# 528/528 [==============================] - 45s 84ms/step - loss: 2.0134e-05 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9775
# Epoch 116/120
# 528/528 [==============================] - 46s 88ms/step - loss: 1.9840e-05 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9775
# Epoch 117/120
# 528/528 [==============================] - 46s 87ms/step - loss: 1.9555e-05 - accuracy: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9775
# Epoch 118/120
# 528/528 [==============================] - 48s 90ms/step - loss: 1.9278e-05 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9775
# Epoch 119/120
# 528/528 [==============================] - 49s 93ms/step - loss: 1.9007e-05 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.9775
# Epoch 120/120
# 528/528 [==============================] - 46s 87ms/step - loss: 1.8744e-05 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9775

# %%
model.save("/content/gdrive/MyDrive/Models/CRNN-LSTM-GRU-WithoutExtraDense.h5")
score = model.evaluate(X_test, y_test)
print(score)
# Out:
# 66/66 [==============================] - 1s 22ms/step - loss: 0.1369 - accuracy: 0.9815
# [0.13692377507686615, 0.9815078377723694]

# %% [markdown]
# ## METRICS

# %%
pip install plot_keras_history
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plot_keras_history
#   Downloading plot_keras_history-1.1.38.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (3.5.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.7.3)
# Collecting support_developer>=1.0.2
#   Downloading support_developer-1.0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sanitize_ml_labels>=1.0.48
#   Downloading sanitize_ml_labels-1.0.50.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 KB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting compress_json
#   Downloading compress_json-1.0.8.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (4.38.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->plot_keras_history) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.15.0)
# Building wheels for collected packages: plot_keras_history, sanitize_ml_labels, support_developer, compress_json
#   Building wheel for plot_keras_history (setup.py) ... done
#   Created wheel for plot_keras_history: filename=plot_keras_history-1.1.38-py3-none-any.whl size=9472 sha256=f8e0d4bdf865c225bac20df4058a1a36d5ae602becb157c0c74c070d2b05f1b7
#   Stored in directory: /root/.cache/pip/wheels/97/a5/76/35ae3e15da1ce4530de8591b0bcd7716f6d6752a4808f01c04
#   Building wheel for sanitize_ml_labels (setup.py) ... done
#   Created wheel for sanitize_ml_labels: filename=sanitize_ml_labels-1.0.50-py3-none-any.whl size=320514 sha256=c77d5cd1c5cf6986ac9d2783a6c19401b0ee7673c104a13ffbbe786fdd616917
#   Stored in directory: /root/.cache/pip/wheels/a3/5f/ba/ddd191edb6c749a63cffabd28714d5600b5b58014daf7434a8
#   Building wheel for support_developer (setup.py) ... done
#   Created wheel for support_developer: filename=support_developer-1.0.5-py3-none-any.whl size=5650 sha256=045d63c8f662ff5e623c726f75606749334032773a6f363946bf1df0e2318191
#   Stored in directory: /root/.cache/pip/wheels/11/5e/63/51e84640e77a7dc5f1e5f5eb597e8f1bc730a2818ee5c3fc03
#   Building wheel for compress_json (setup.py) ... done
#   Created wheel for compress_json: filename=compress_json-1.0.8-py3-none-any.whl size=4733 sha256=e1a66306a2b947d59ec19c04cc0ef9806f26a01c403e47c03d2bc957d17943d8
#   Stored in directory: /root/.cache/pip/wheels/fe/36/4b/69aaa23fc0ea813dc1f8cca3372bff314abed354cac20a1cb9
# Successfully built plot_keras_history sanitize_ml_labels support_developer compress_json
# Installing collected packages: support_developer, compress_json, sanitize_ml_labels, plot_keras_history
# Successfully installed compress_json-1.0.8 plot_keras_history-1.1.38 sanitize_ml_labels-1.0.50 support_developer-1.0.5

# %%
from plot_keras_history import show_history, plot_history
plot_history(history)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>,
#         <AxesSubplot:title={'center':'Accuracy'}, xlabel='Epochs', ylabel='Accuracy'>],
#        dtype=object))

# %%
import matplotlib.pyplot as plt
import itertools
import numpy as np

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
print("Model Classification Report: \n")
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
print(classification_report(np.argmax(y_test, axis=1), y_pred))
plot_confusion_matrix(cm, classes=["Does not have Wake Word", "Has Wake Word"])
# Out:
# Model Classification Report:
#
# 66/66 [==============================] - 3s 23ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1049
#            1       0.98      0.98      0.98      1060
#
#     accuracy                           0.98      2109
#    macro avg       0.98      0.98      0.98      2109
# weighted avg       0.98      0.98      0.98      2109
#
# Confusion matrix, without normalization
# [[1031   18]
#  [  21 1039]]

# %% [markdown]
# ##PREDICTION & LATENCY

# %%
pip install spafe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spafe
#   Downloading spafe-0.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.22.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from spafe) (4.5.0)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.7.3)
# Installing collected packages: spafe
# Successfully installed spafe-0.3.1

# %%
import spafe
from spafe.features.lfcc import lfcc
import pywt

# %%
def predict(audio):
  audio_data, sr = librosa.load(audio)

  wavelet = 'db4'
  level = 4
  coeffs = pywt.wavedec(audio_data, wavelet, level=level)
  threshold = np.median(np.abs(coeffs[-level])) / 0.6745
  for i in range(1, len(coeffs)):
    coeffs[i] = pywt.threshold(coeffs[i], threshold)
  denoised_audio = pywt.waverec(coeffs, wavelet)

  lfccs  = lfcc(denoised_audio, fs = sr, num_ceps=13)
  lfccs_processed = np.mean(lfccs.T, axis=0) # some pre-processing
  lfccs_new = np.expand_dims(np.asarray(lfccs_processed), axis=0)
  predictions = model.predict(lfccs_new)
  return predictions

# %%
audio_for_pred = "/content/gdrive/MyDrive/Marvin/marvin (170).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 28ms/step
# [[1. 0.]]

# %%
audio_for_pred = "/content/gdrive/MyDrive/False/yes (824).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 51ms/step
# [[1. 0.]]
