# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa, librosa.display

import tensorflow as tf

# %%
X_test = np.load('/content/gdrive/MyDrive/data/Augmented1/X_test.npy')
y_test = np.load('/content/gdrive/MyDrive/data/Augmented1/y_test.npy')

# %%
from tensorflow import keras
# model = keras.models.load_model('/content/gdrive/MyDrive/Models/CRNNGRULSTMWithAttentionWithoutDenseV3.h5')
# model = keras.models.load_model('/content/gdrive/MyDrive/Models/CRNNGRULSTMWithExtraDenseWithRegularizerwithAttentionLiteV2.h5')
model = keras.models.load_model('/content/gdrive/MyDrive/Models/CRNN_GRULSTM_Standalone_WithDense_Lite.h5')

# %%
from sklearn.utils import shuffle
#shuffle test audios
shuffled_audios, shuffled_labels = shuffle(X_test, y_test)
print(shuffled_audios.shape)
print(shuffled_labels.shape)
# Out:
# (2109, 98)
# (2109, 2)

# %%
import time

# %%
model_run_times= []

# %%
def compute_latency(test_audios):
  for i in test_audios:
    start = time.time()
    model.predict(np.expand_dims(i, axis=0))
    end = time.time()
    model_run_times.append(end - start)

# %%
model_run_times= []
compute_latency(X_test)
# Out:
# ...
# 1/1 [==============================] - 0s 23ms/step
# ...
# ...
# 1/1 [==============================] - 0s 26ms/step

# %%
print("CRNN GRU LSTM With Dense Without Attention \nAverage Model Latency: %.2f ms" % round(np.mean(model_run_times)*1000,2))
# Out:
# CRNN GRU LSTM With Dense Without Attention
# Average Model Latency: 80.57 ms
