# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa, librosa.display

import tensorflow as tf

# %%
X_test = np.load('/content/gdrive/MyDrive/Colab Notebooks/FYP/WaveletTransformDenoised/X_test.npy')
y_test = np.load('/content/gdrive/MyDrive/Colab Notebooks/FYP/WaveletTransformDenoised/y_test.npy')

# %%
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1, 1)

# %%
from tensorflow import keras
import keras.backend as K
model = keras.models.load_model('/content/gdrive/MyDrive/Colab Notebooks/Experiments/TinyCRNN-.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-211de22f48c1> in <module>
#       1 from tensorflow import keras
#       2 import keras.backend as K
# ----> 3 model = keras.models.load_model('/content/gdrive/MyDrive/Colab Notebooks/FYP/TinyCRNN.h5')
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/layers/core/lambda_layer.py in <lambda>(x)
#
# NameError: Exception encountered when calling layer "lambda_9" (type Lambda).
#
# name 'attention_size' is not defined
#
# ...

# %%
from sklearn.utils import shuffle
#shuffle test audios
shuffled_audios, shuffled_labels = shuffle(X_test, y_test)
print(shuffled_audios.shape)
print(shuffled_labels.shape)

# %%
import time

# %%
model_run_times= []

# %%
def compute_latency(test_audios):
  for i in test_audios:
    start = time.time()
    model.predict(np.expand_dims(i, axis=0))
    end = time.time()
    model_run_times.append(end - start)

# %%
model_run_times= []
compute_latency(X_test)

# %%
print("TinyCRNN.h5\nAverage Model Latency: %.2f ms" % round(np.mean(model_run_times)*1000,2))
