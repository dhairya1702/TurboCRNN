# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa, librosa.display

import tensorflow as tf 
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras import Sequential
from tensorflow import keras
from tensorflow.keras.layers import Input, LSTM, GRU, Dense, Embedding, Conv1D, MaxPooling1D, Activation, Dropout
from tensorflow.keras.layers import Reshape, Softmax, Permute, Multiply, dot, concatenate
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ## DATALOADER

# %%
X_train = np.load('/content/gdrive/MyDrive/data/Augmented1/X_train.npy')
y_train = np.load('/content/gdrive/MyDrive/data/Augmented1/y_train.npy')
X_test = np.load('/content/gdrive/MyDrive/data/Augmented1/X_test.npy')
y_test = np.load('/content/gdrive/MyDrive/data/Augmented1/y_test.npy')
X_val = np.load('/content/gdrive/MyDrive/data/Augmented1/X_val.npy')
y_val = np.load('/content/gdrive/MyDrive/data/Augmented1/y_val.npy')

# %%
X_train[0].shape
# Out:
# (98,)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (16893, 98) (16893, 2)
# (2109, 98) (2109, 2)
# (2088, 98) (2088, 2)

# %% [markdown]
# ## CRNN - Review Later

# %%
inputs = Input(shape=(98,1))
conv1 = Conv1D(32, 5, activation='relu',kernel_regularizer=l2(0.01))(inputs)
pool1 = MaxPooling1D(2)(conv1)
conv2 = Conv1D(64, 5, activation='relu')(pool1)
pool2 = MaxPooling1D(2)(conv2)
conv3 = Conv1D(128, 5, activation='relu')(pool2)
pool3 = MaxPooling1D(2)(conv3)

gru1 = GRU(128, return_sequences=True)(pool3)
gru1 = Dropout(0.2)(gru1)
lstm1 = LSTM(128)(gru1)

q = Dense(128)(lstm1)
k = Dense(128)(lstm1)
v = Dense(128)(lstm1)

q = Reshape((1, 128))(q)
k = Reshape((1, 128))(k)
v = Reshape((1, 128))(v)

attention = dot([q, k], axes=[2, 2])
attention = Activation('softmax')(attention)

output = dot([attention, v], axes=[2, 1])
output = Reshape((128,))(output)

dense1 = Dense(32, activation='softmax')(output)
dense1 = Dropout(0.5)(dense1)

output = Dense(2, activation='softmax')(dense1)

model = Model(inputs=inputs, outputs=output)

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 98, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 94, 32)       192         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 47, 32)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 43, 64)       10304       ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 21, 64)      0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 17, 128)      41088       ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 8, 128)      0           ['conv1d_2[0][0]']
#
#  gru (GRU)                      (None, 8, 128)       99072       ['max_pooling1d_2[0][0]']
#
#  dropout (Dropout)              (None, 8, 128)       0           ['gru[0][0]']
#
#  lstm (LSTM)                    (None, 128)          131584      ['dropout[0][0]']
#
#  dense (Dense)                  (None, 128)          16512       ['lstm[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16512       ['lstm[0][0]']
#
#  reshape (Reshape)              (None, 1, 128)       0           ['dense[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 128)       0           ['dense_1[0][0]']
#
#  dot (Dot)                      (None, 1, 1)         0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16512       ['lstm[0][0]']
#
#  activation (Activation)        (None, 1, 1)         0           ['dot[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 128)       0           ['dense_2[0][0]']
#
#  dot_1 (Dot)                    (None, 1, 128)       0           ['activation[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 128)          0           ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 32)           4128        ['reshape_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 32)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 2)            66          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 335,970
# Trainable params: 335,970
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=tf.keras.optimizers.Adam(amsgrad=True),
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 120, shuffle = False)
# Out:
# Epoch 1/120
# 528/528 [==============================] - 24s 14ms/step - loss: 0.6046 - accuracy: 0.6815 - val_loss: 0.4528 - val_accuracy: 0.8554
# Epoch 2/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.3939 - accuracy: 0.8901 - val_loss: 0.2966 - val_accuracy: 0.9148
# Epoch 3/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.3107 - accuracy: 0.9055 - val_loss: 0.2323 - val_accuracy: 0.9373
# Epoch 4/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2672 - accuracy: 0.9170 - val_loss: 0.2397 - val_accuracy: 0.9176
# Epoch 5/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.2465 - accuracy: 0.9241 - val_loss: 0.2067 - val_accuracy: 0.9373
# Epoch 6/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.2240 - accuracy: 0.9262 - val_loss: 0.1770 - val_accuracy: 0.9411
# Epoch 7/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.2052 - accuracy: 0.9354 - val_loss: 0.1670 - val_accuracy: 0.9507
# Epoch 8/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.1920 - accuracy: 0.9433 - val_loss: 0.1939 - val_accuracy: 0.9277
# Epoch 9/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.1776 - accuracy: 0.9490 - val_loss: 0.1463 - val_accuracy: 0.9559
# Epoch 10/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1699 - accuracy: 0.9574 - val_loss: 0.1497 - val_accuracy: 0.9521
# Epoch 11/120
# 528/528 [==============================] - 6s 10ms/step - loss: 0.1620 - accuracy: 0.9615 - val_loss: 0.1422 - val_accuracy: 0.9555
# Epoch 12/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.1537 - accuracy: 0.9624 - val_loss: 0.1528 - val_accuracy: 0.9535
# Epoch 13/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.1440 - accuracy: 0.9707 - val_loss: 0.1331 - val_accuracy: 0.9559
# Epoch 14/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.1363 - accuracy: 0.9679 - val_loss: 0.1338 - val_accuracy: 0.9564
# Epoch 15/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1348 - accuracy: 0.9686 - val_loss: 0.1666 - val_accuracy: 0.9406
# Epoch 16/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.1277 - accuracy: 0.9696 - val_loss: 0.1339 - val_accuracy: 0.9574
# Epoch 17/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.1154 - accuracy: 0.9745 - val_loss: 0.1251 - val_accuracy: 0.9607
# Epoch 18/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.1164 - accuracy: 0.9737 - val_loss: 0.1247 - val_accuracy: 0.9607
# Epoch 19/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1064 - accuracy: 0.9756 - val_loss: 0.1275 - val_accuracy: 0.9607
# Epoch 20/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.1015 - accuracy: 0.9784 - val_loss: 0.1217 - val_accuracy: 0.9631
# Epoch 21/120
# 528/528 [==============================] - 6s 10ms/step - loss: 0.1018 - accuracy: 0.9757 - val_loss: 0.1229 - val_accuracy: 0.9555
# Epoch 22/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.1011 - accuracy: 0.9775 - val_loss: 0.1123 - val_accuracy: 0.9674
# Epoch 23/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0835 - accuracy: 0.9825 - val_loss: 0.1163 - val_accuracy: 0.9679
# Epoch 24/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0910 - accuracy: 0.9772 - val_loss: 0.1326 - val_accuracy: 0.9598
# Epoch 25/120
# 528/528 [==============================] - 6s 10ms/step - loss: 0.0839 - accuracy: 0.9819 - val_loss: 0.1223 - val_accuracy: 0.9655
# Epoch 26/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0820 - accuracy: 0.9811 - val_loss: 0.1139 - val_accuracy: 0.9689
# Epoch 27/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0686 - accuracy: 0.9860 - val_loss: 0.1136 - val_accuracy: 0.9698
# Epoch 28/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0625 - accuracy: 0.9888 - val_loss: 0.1196 - val_accuracy: 0.9693
# Epoch 29/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0673 - accuracy: 0.9878 - val_loss: 0.2572 - val_accuracy: 0.9195
# Epoch 30/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0703 - accuracy: 0.9852 - val_loss: 0.1131 - val_accuracy: 0.9689
# Epoch 31/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0637 - accuracy: 0.9877 - val_loss: 0.1492 - val_accuracy: 0.9631
# Epoch 32/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0613 - accuracy: 0.9895 - val_loss: 0.1330 - val_accuracy: 0.9665
# Epoch 33/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0687 - accuracy: 0.9855 - val_loss: 0.1136 - val_accuracy: 0.9708
# Epoch 34/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.1086 - val_accuracy: 0.9737
# Epoch 35/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0487 - accuracy: 0.9924 - val_loss: 0.1371 - val_accuracy: 0.9679
# Epoch 36/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0645 - accuracy: 0.9868 - val_loss: 0.1483 - val_accuracy: 0.9626
# Epoch 37/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0511 - accuracy: 0.9908 - val_loss: 0.1161 - val_accuracy: 0.9713
# Epoch 38/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0522 - accuracy: 0.9910 - val_loss: 0.1050 - val_accuracy: 0.9751
# Epoch 39/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0453 - accuracy: 0.9918 - val_loss: 0.1165 - val_accuracy: 0.9727
# Epoch 40/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0514 - accuracy: 0.9905 - val_loss: 0.1168 - val_accuracy: 0.9732
# Epoch 41/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0413 - accuracy: 0.9940 - val_loss: 0.1295 - val_accuracy: 0.9732
# Epoch 42/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0412 - accuracy: 0.9933 - val_loss: 0.1263 - val_accuracy: 0.9727
# Epoch 43/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0410 - accuracy: 0.9938 - val_loss: 0.1320 - val_accuracy: 0.9703
# Epoch 44/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0498 - accuracy: 0.9915 - val_loss: 0.1219 - val_accuracy: 0.9737
# Epoch 45/120
# 528/528 [==============================] - 7s 13ms/step - loss: 0.0473 - accuracy: 0.9911 - val_loss: 0.1171 - val_accuracy: 0.9737
# Epoch 46/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0481 - accuracy: 0.9909 - val_loss: 0.1134 - val_accuracy: 0.9713
# Epoch 47/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0386 - accuracy: 0.9936 - val_loss: 0.1224 - val_accuracy: 0.9737
# Epoch 48/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0349 - accuracy: 0.9951 - val_loss: 0.1414 - val_accuracy: 0.9679
# Epoch 49/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0361 - accuracy: 0.9945 - val_loss: 0.1341 - val_accuracy: 0.9708
# Epoch 50/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0336 - accuracy: 0.9951 - val_loss: 0.1334 - val_accuracy: 0.9727
# Epoch 51/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0416 - accuracy: 0.9925 - val_loss: 0.1194 - val_accuracy: 0.9703
# Epoch 52/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0425 - accuracy: 0.9930 - val_loss: 0.1249 - val_accuracy: 0.9713
# Epoch 53/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0342 - accuracy: 0.9953 - val_loss: 0.1152 - val_accuracy: 0.9756
# Epoch 54/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0263 - accuracy: 0.9978 - val_loss: 0.1279 - val_accuracy: 0.9741
# Epoch 55/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0258 - accuracy: 0.9972 - val_loss: 0.1402 - val_accuracy: 0.9732
# Epoch 56/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0345 - accuracy: 0.9941 - val_loss: 0.1204 - val_accuracy: 0.9746
# Epoch 57/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0246 - accuracy: 0.9975 - val_loss: 0.1403 - val_accuracy: 0.9722
# Epoch 58/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0261 - accuracy: 0.9969 - val_loss: 0.1987 - val_accuracy: 0.9602
# Epoch 59/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0493 - accuracy: 0.9902 - val_loss: 0.1224 - val_accuracy: 0.9717
# Epoch 60/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0319 - accuracy: 0.9950 - val_loss: 0.1359 - val_accuracy: 0.9713
# Epoch 61/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0263 - accuracy: 0.9962 - val_loss: 0.1429 - val_accuracy: 0.9717
# Epoch 62/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0263 - accuracy: 0.9965 - val_loss: 0.1468 - val_accuracy: 0.9727
# Epoch 63/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0251 - accuracy: 0.9967 - val_loss: 0.1595 - val_accuracy: 0.9703
# Epoch 64/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0243 - accuracy: 0.9973 - val_loss: 0.1453 - val_accuracy: 0.9717
# Epoch 65/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0322 - accuracy: 0.9942 - val_loss: 0.1259 - val_accuracy: 0.9741
# Epoch 66/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0271 - accuracy: 0.9963 - val_loss: 0.1319 - val_accuracy: 0.9751
# Epoch 67/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0394 - accuracy: 0.9934 - val_loss: 0.4018 - val_accuracy: 0.8879
# Epoch 68/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0755 - accuracy: 0.9777 - val_loss: 0.1194 - val_accuracy: 0.9756
# Epoch 69/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0367 - accuracy: 0.9935 - val_loss: 0.1276 - val_accuracy: 0.9693
# Epoch 70/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0225 - accuracy: 0.9980 - val_loss: 0.1333 - val_accuracy: 0.9751
# Epoch 71/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0216 - accuracy: 0.9980 - val_loss: 0.1398 - val_accuracy: 0.9751
# Epoch 72/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0288 - accuracy: 0.9956 - val_loss: 0.1456 - val_accuracy: 0.9732
# Epoch 73/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0294 - accuracy: 0.9960 - val_loss: 0.1391 - val_accuracy: 0.9722
# Epoch 74/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0241 - accuracy: 0.9969 - val_loss: 0.1395 - val_accuracy: 0.9741
# Epoch 75/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0213 - accuracy: 0.9978 - val_loss: 0.1371 - val_accuracy: 0.9732
# Epoch 76/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0188 - accuracy: 0.9985 - val_loss: 0.1568 - val_accuracy: 0.9727
# Epoch 77/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0194 - accuracy: 0.9985 - val_loss: 0.1634 - val_accuracy: 0.9698
# Epoch 78/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0243 - accuracy: 0.9966 - val_loss: 0.1389 - val_accuracy: 0.9751
# Epoch 79/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0311 - accuracy: 0.9944 - val_loss: 0.1247 - val_accuracy: 0.9713
# Epoch 80/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0215 - accuracy: 0.9972 - val_loss: 0.1449 - val_accuracy: 0.9741
# Epoch 81/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0178 - accuracy: 0.9986 - val_loss: 0.1516 - val_accuracy: 0.9708
# Epoch 82/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0180 - accuracy: 0.9988 - val_loss: 0.1493 - val_accuracy: 0.9732
# Epoch 83/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0189 - accuracy: 0.9985 - val_loss: 0.1524 - val_accuracy: 0.9722
# Epoch 84/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0298 - accuracy: 0.9944 - val_loss: 0.1404 - val_accuracy: 0.9713
# Epoch 85/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0183 - accuracy: 0.9980 - val_loss: 0.1573 - val_accuracy: 0.9717
# Epoch 86/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0191 - accuracy: 0.9980 - val_loss: 0.1320 - val_accuracy: 0.9741
# Epoch 87/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0180 - accuracy: 0.9986 - val_loss: 0.1525 - val_accuracy: 0.9713
# Epoch 88/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0186 - accuracy: 0.9978 - val_loss: 0.1491 - val_accuracy: 0.9737
# Epoch 89/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0170 - accuracy: 0.9984 - val_loss: 0.1520 - val_accuracy: 0.9741
# Epoch 90/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0158 - accuracy: 0.9981 - val_loss: 0.1461 - val_accuracy: 0.9746
# Epoch 91/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0154 - accuracy: 0.9989 - val_loss: 0.1593 - val_accuracy: 0.9727
# Epoch 92/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0155 - accuracy: 0.9987 - val_loss: 0.1572 - val_accuracy: 0.9717
# Epoch 93/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0164 - accuracy: 0.9986 - val_loss: 0.1673 - val_accuracy: 0.9717
# Epoch 94/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0291 - accuracy: 0.9948 - val_loss: 0.1489 - val_accuracy: 0.9717
# Epoch 95/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0239 - accuracy: 0.9967 - val_loss: 0.1464 - val_accuracy: 0.9722
# Epoch 96/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0163 - accuracy: 0.9982 - val_loss: 0.1474 - val_accuracy: 0.9746
# Epoch 97/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0176 - accuracy: 0.9983 - val_loss: 0.1562 - val_accuracy: 0.9722
# Epoch 98/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0159 - accuracy: 0.9987 - val_loss: 0.1625 - val_accuracy: 0.9737
# Epoch 99/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0147 - accuracy: 0.9989 - val_loss: 0.1606 - val_accuracy: 0.9737
# Epoch 100/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0141 - accuracy: 0.9989 - val_loss: 0.1645 - val_accuracy: 0.9737
# Epoch 101/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0144 - accuracy: 0.9988 - val_loss: 0.1703 - val_accuracy: 0.9732
# Epoch 102/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0149 - accuracy: 0.9982 - val_loss: 0.1722 - val_accuracy: 0.9727
# Epoch 103/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0144 - accuracy: 0.9987 - val_loss: 0.1698 - val_accuracy: 0.9732
# Epoch 104/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0168 - accuracy: 0.9980 - val_loss: 0.1598 - val_accuracy: 0.9732
# Epoch 105/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0133 - accuracy: 0.9992 - val_loss: 0.1680 - val_accuracy: 0.9732
# Epoch 106/120
# 528/528 [==============================] - 7s 14ms/step - loss: 0.0129 - accuracy: 0.9987 - val_loss: 0.1691 - val_accuracy: 0.9722
# Epoch 107/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0130 - accuracy: 0.9986 - val_loss: 0.1668 - val_accuracy: 0.9717
# Epoch 108/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0137 - accuracy: 0.9986 - val_loss: 0.1708 - val_accuracy: 0.9722
# Epoch 109/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0129 - accuracy: 0.9988 - val_loss: 0.1720 - val_accuracy: 0.9722
# Epoch 110/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0126 - accuracy: 0.9987 - val_loss: 0.1686 - val_accuracy: 0.9717
# Epoch 111/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0167 - accuracy: 0.9979 - val_loss: 0.1675 - val_accuracy: 0.9717
# Epoch 112/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0290 - accuracy: 0.9948 - val_loss: 0.1395 - val_accuracy: 0.9713
# Epoch 113/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0152 - accuracy: 0.9977 - val_loss: 0.1419 - val_accuracy: 0.9756
# Epoch 114/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0137 - accuracy: 0.9984 - val_loss: 0.1490 - val_accuracy: 0.9746
# Epoch 115/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0144 - accuracy: 0.9977 - val_loss: 0.1433 - val_accuracy: 0.9751
# Epoch 116/120
# 528/528 [==============================] - 6s 10ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.1650 - val_accuracy: 0.9727
# Epoch 117/120
# 528/528 [==============================] - 6s 10ms/step - loss: 0.0129 - accuracy: 0.9987 - val_loss: 0.1561 - val_accuracy: 0.9722
# Epoch 118/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0122 - accuracy: 0.9988 - val_loss: 0.1502 - val_accuracy: 0.9751
# Epoch 119/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0231 - accuracy: 0.9958 - val_loss: 0.1485 - val_accuracy: 0.9727
# Epoch 120/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0144 - accuracy: 0.9986 - val_loss: 0.1504 - val_accuracy: 0.9741

# %%
model.save("/content/gdrive/MyDrive/Models/WithExtraDenseWithRegularizerwithAttention.h5")
print("Model Score: \n")
score = model.evaluate(X_test, y_test)
print(score)
# Out:
# Model Score:
#
# 66/66 [==============================] - 0s 5ms/step - loss: 0.1137 - accuracy: 0.9815
# [0.1137094497680664, 0.9815078377723694]

# %% [markdown]
# ##METRICS

# %%
pip install plot_keras_history
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plot_keras_history
#   Downloading plot_keras_history-1.1.38.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (3.5.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.7.3)
# Collecting support_developer>=1.0.2
#   Downloading support_developer-1.0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sanitize_ml_labels>=1.0.48
#   Downloading sanitize_ml_labels-1.0.50.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 KB 24.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting compress_json
#   Downloading compress_json-1.0.8.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (23.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->plot_keras_history) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.15.0)
# Building wheels for collected packages: plot_keras_history, sanitize_ml_labels, support_developer, compress_json
#   Building wheel for plot_keras_history (setup.py) ... done
#   Created wheel for plot_keras_history: filename=plot_keras_history-1.1.38-py3-none-any.whl size=9472 sha256=c7df752b13051467f30e6bc7b33f0aa8dea6773aa49f6f6ce8bf47e7a67b3dfa
#   Stored in directory: /root/.cache/pip/wheels/97/a5/76/35ae3e15da1ce4530de8591b0bcd7716f6d6752a4808f01c04
#   Building wheel for sanitize_ml_labels (setup.py) ... done
#   Created wheel for sanitize_ml_labels: filename=sanitize_ml_labels-1.0.50-py3-none-any.whl size=320514 sha256=daf1290416227f92ff4abdacd5ab5d0ed0e54cbf779403caf4f411e89fa58a38
#   Stored in directory: /root/.cache/pip/wheels/a3/5f/ba/ddd191edb6c749a63cffabd28714d5600b5b58014daf7434a8
#   Building wheel for support_developer (setup.py) ... done
#   Created wheel for support_developer: filename=support_developer-1.0.5-py3-none-any.whl size=5650 sha256=e6bee5bc6d7049c10742c3f19e0908b50507c72e276b00cf4ab7b05bdd95ce23
#   Stored in directory: /root/.cache/pip/wheels/11/5e/63/51e84640e77a7dc5f1e5f5eb597e8f1bc730a2818ee5c3fc03
#   Building wheel for compress_json (setup.py) ... done
#   Created wheel for compress_json: filename=compress_json-1.0.8-py3-none-any.whl size=4733 sha256=d318d491b5f28f5bdc9c0683e25d39d2349727a0465e34a87f4c0cf862301750
#   Stored in directory: /root/.cache/pip/wheels/fe/36/4b/69aaa23fc0ea813dc1f8cca3372bff314abed354cac20a1cb9
# Successfully built plot_keras_history sanitize_ml_labels support_developer compress_json
# Installing collected packages: support_developer, compress_json, sanitize_ml_labels, plot_keras_history
# Successfully installed compress_json-1.0.8 plot_keras_history-1.1.38 sanitize_ml_labels-1.0.50 support_developer-1.0.5

# %%
from plot_keras_history import show_history, plot_history
plot_history(history)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>,
#         <AxesSubplot:title={'center':'Accuracy'}, xlabel='Epochs', ylabel='Accuracy'>],
#        dtype=object))

# %%
import matplotlib.pyplot as plt
import itertools
import numpy as np

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
print("Model Classification Report: \n")
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
print(classification_report(np.argmax(y_test, axis=1), y_pred))
plot_confusion_matrix(cm, classes=["Does not have Wake Word", "Has Wake Word"])
# Out:
# Model Classification Report:
#
# 66/66 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1049
#            1       0.98      0.98      0.98      1060
#
#     accuracy                           0.98      2109
#    macro avg       0.98      0.98      0.98      2109
# weighted avg       0.98      0.98      0.98      2109
#
# Confusion matrix, without normalization
# [[1031   18]
#  [  18 1042]]

# %% [markdown]
# ##PREDICTIONS & LATENCY

# %%
pip install spafe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spafe
#   Downloading spafe-0.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 KB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from spafe) (4.5.0)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.7.3)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.22.4)
# Installing collected packages: spafe
# Successfully installed spafe-0.3.1

# %%
import spafe
from spafe.features.lfcc import lfcc
import pywt

# %%
def predict(audio):
  audio_data, sr = librosa.load(audio)

  wavelet = 'db4'
  level = 4
  coeffs = pywt.wavedec(audio_data, wavelet, level=level)
  threshold = np.median(np.abs(coeffs[-level])) / 0.6745
  for i in range(1, len(coeffs)):
    coeffs[i] = pywt.threshold(coeffs[i], threshold)
  denoised_audio = pywt.waverec(coeffs, wavelet)

  lfccs  = lfcc(denoised_audio, fs = sr, num_ceps=13)
  lfccs_processed = np.mean(lfccs.T, axis=0) # some pre-processing
  lfccs_new = np.expand_dims(np.asarray(lfccs_processed), axis=0)
  predictions = model.predict(lfccs_new)
  return predictions

# %%
audio_for_pred = "/content/gdrive/MyDrive/Marvin/marvin (170).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [[0. 1.]]

# %%
audio_for_pred = "/content/gdrive/MyDrive/False/yes (824).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 26ms/step
# [[1. 0.]]
