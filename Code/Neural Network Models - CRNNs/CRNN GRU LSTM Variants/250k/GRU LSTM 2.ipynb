# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa, librosa.display

import tensorflow as tf 
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, GRU, Input, Conv1D, MaxPooling1D
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ## DATALOADER

# %%
X_train = np.load('/content/gdrive/MyDrive/data/Augmented1/X_train.npy')
y_train = np.load('/content/gdrive/MyDrive/data/Augmented1/y_train.npy')
X_test = np.load('/content/gdrive/MyDrive/data/Augmented1/X_test.npy')
y_test = np.load('/content/gdrive/MyDrive/data/Augmented1/y_test.npy')
X_val = np.load('/content/gdrive/MyDrive/data/Augmented1/X_val.npy')
y_val = np.load('/content/gdrive/MyDrive/data/Augmented1/y_val.npy')

# %%
X_train[0].shape
# Out:
# (98,)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (16893, 98) (16893, 2)
# (2109, 98) (2109, 2)
# (2088, 98) (2088, 2)

# %% [markdown]
# ## CRNN - Review Later

# %%
from keras.layers import Input, LSTM, GRU, Dense, Embedding, Conv1D, MaxPooling1D, Activation
from keras.layers import Reshape, Softmax, Permute, Multiply, dot, concatenate
from keras.layers import BatchNormalization
from keras.models import Model

inputs = Input(shape=(98,1))
conv1 = Conv1D(32, 5, activation='relu')(inputs)
pool1 = MaxPooling1D(2)(conv1)
conv2 = Conv1D(64, 5, activation='relu')(pool1)
pool2 = MaxPooling1D(2)(conv2)
conv3 = Conv1D(128, 5, activation='relu')(pool2)
pool3 = MaxPooling1D(2)(conv3)

gru1 = GRU(128, return_sequences=True)(pool3)
lstm1 = LSTM(128)(gru1)

q = Dense(128)(lstm1)
k = Dense(128)(lstm1)
v = Dense(128)(lstm1)

q = Reshape((1, 128))(q)
k = Reshape((1, 128))(k)
v = Reshape((1, 128))(v)

attention = dot([q, k], axes=[2, 2])
attention = Activation('softmax')(attention)

output = dot([attention, v], axes=[2, 1])
output = Reshape((128,))(output)

output = Dense(2, activation='softmax')(output)

model = Model(inputs=inputs, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(amsgrad=True), loss='categorical_crossentropy', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 98, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 94, 32)       192         ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 47, 32)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 43, 64)       10304       ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 21, 64)      0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 17, 128)      41088       ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 8, 128)      0           ['conv1d_2[0][0]']
#
#  gru (GRU)                      (None, 8, 128)       99072       ['max_pooling1d_2[0][0]']
#
#  lstm (LSTM)                    (None, 128)          131584      ['gru[0][0]']
#
#  dense (Dense)                  (None, 128)          16512       ['lstm[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16512       ['lstm[0][0]']
#
#  reshape (Reshape)              (None, 1, 128)       0           ['dense[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 128)       0           ['dense_1[0][0]']
#
#  dot (Dot)                      (None, 1, 1)         0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  dense_2 (Dense)                (None, 128)          16512       ['lstm[0][0]']
#
#  activation (Activation)        (None, 1, 1)         0           ['dot[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 128)       0           ['dense_2[0][0]']
#
#  dot_1 (Dot)                    (None, 1, 128)       0           ['activation[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 128)          0           ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            258         ['reshape_3[0][0]']
#
# ==================================================================================================
# Total params: 332,034
# Trainable params: 332,034
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train, validation_data = (X_val, y_val), epochs = 120, shuffle = False)
# Out:
# Epoch 1/120
# 528/528 [==============================] - 24s 13ms/step - loss: 0.3675 - accuracy: 0.8277 - val_loss: 0.2184 - val_accuracy: 0.9191
# Epoch 2/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.1938 - accuracy: 0.9286 - val_loss: 0.1984 - val_accuracy: 0.9239
# Epoch 3/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.1635 - accuracy: 0.9396 - val_loss: 0.1790 - val_accuracy: 0.9339
# Epoch 4/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.1407 - accuracy: 0.9490 - val_loss: 0.1733 - val_accuracy: 0.9377
# Epoch 5/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1253 - accuracy: 0.9538 - val_loss: 0.1453 - val_accuracy: 0.9478
# Epoch 6/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.1096 - accuracy: 0.9596 - val_loss: 0.1451 - val_accuracy: 0.9468
# Epoch 7/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0979 - accuracy: 0.9664 - val_loss: 0.1377 - val_accuracy: 0.9497
# Epoch 8/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0879 - accuracy: 0.9690 - val_loss: 0.1399 - val_accuracy: 0.9579
# Epoch 9/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0785 - accuracy: 0.9716 - val_loss: 0.1387 - val_accuracy: 0.9535
# Epoch 10/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0729 - accuracy: 0.9738 - val_loss: 0.1443 - val_accuracy: 0.9540
# Epoch 11/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0657 - accuracy: 0.9762 - val_loss: 0.1301 - val_accuracy: 0.9607
# Epoch 12/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0569 - accuracy: 0.9805 - val_loss: 0.1803 - val_accuracy: 0.9511
# Epoch 13/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0520 - accuracy: 0.9823 - val_loss: 0.1594 - val_accuracy: 0.9564
# Epoch 14/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0464 - accuracy: 0.9825 - val_loss: 0.1644 - val_accuracy: 0.9555
# Epoch 15/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0374 - accuracy: 0.9861 - val_loss: 0.1386 - val_accuracy: 0.9607
# Epoch 16/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0363 - accuracy: 0.9872 - val_loss: 0.1199 - val_accuracy: 0.9674
# Epoch 17/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0326 - accuracy: 0.9882 - val_loss: 0.1253 - val_accuracy: 0.9670
# Epoch 18/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0329 - accuracy: 0.9877 - val_loss: 0.1662 - val_accuracy: 0.9607
# Epoch 19/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0306 - accuracy: 0.9887 - val_loss: 0.1257 - val_accuracy: 0.9674
# Epoch 20/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.1397 - val_accuracy: 0.9665
# Epoch 21/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0267 - accuracy: 0.9906 - val_loss: 0.1274 - val_accuracy: 0.9698
# Epoch 22/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0184 - accuracy: 0.9925 - val_loss: 0.1448 - val_accuracy: 0.9684
# Epoch 23/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0172 - accuracy: 0.9934 - val_loss: 0.1289 - val_accuracy: 0.9732
# Epoch 24/120
# 528/528 [==============================] - 5s 10ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0975 - val_accuracy: 0.9794
# Epoch 25/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.1335 - val_accuracy: 0.9737
# Epoch 26/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.1753 - val_accuracy: 0.9732
# Epoch 27/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0221 - accuracy: 0.9933 - val_loss: 0.1327 - val_accuracy: 0.9732
# Epoch 28/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.1428 - val_accuracy: 0.9756
# Epoch 29/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.1418 - val_accuracy: 0.9732
# Epoch 30/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.1056 - val_accuracy: 0.9761
# Epoch 31/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.1242 - val_accuracy: 0.9746
# Epoch 32/120
# 528/528 [==============================] - 6s 12ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.1119 - val_accuracy: 0.9765
# Epoch 33/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.1408 - val_accuracy: 0.9722
# Epoch 34/120
# 528/528 [==============================] - 6s 11ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1453 - val_accuracy: 0.9727
# Epoch 35/120
# 528/528 [==============================] - 5s 9ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1493 - val_accuracy: 0.9751
# Epoch 36/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.7600e-04 - accuracy: 1.0000 - val_loss: 0.1781 - val_accuracy: 0.9732
# Epoch 37/120
# 528/528 [==============================] - 5s 10ms/step - loss: 1.2772e-04 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9737
# Epoch 38/120
# 528/528 [==============================] - 5s 9ms/step - loss: 5.3495e-05 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9737
# Epoch 39/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.9867e-05 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9737
# Epoch 40/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.2993e-05 - accuracy: 1.0000 - val_loss: 0.1750 - val_accuracy: 0.9732
# Epoch 41/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.8222e-05 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9732
# Epoch 42/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.4686e-05 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9732
# Epoch 43/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.1927e-05 - accuracy: 1.0000 - val_loss: 0.1785 - val_accuracy: 0.9732
# Epoch 44/120
# 528/528 [==============================] - 6s 11ms/step - loss: 1.9716e-05 - accuracy: 1.0000 - val_loss: 0.1796 - val_accuracy: 0.9732
# Epoch 45/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.7894e-05 - accuracy: 1.0000 - val_loss: 0.1806 - val_accuracy: 0.9732
# Epoch 46/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.6384e-05 - accuracy: 1.0000 - val_loss: 0.1815 - val_accuracy: 0.9732
# Epoch 47/120
# 528/528 [==============================] - 6s 11ms/step - loss: 1.5096e-05 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9732
# Epoch 48/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.3995e-05 - accuracy: 1.0000 - val_loss: 0.1832 - val_accuracy: 0.9732
# Epoch 49/120
# 528/528 [==============================] - 6s 11ms/step - loss: 1.3032e-05 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9732
# Epoch 50/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.2193e-05 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9732
# Epoch 51/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.1450e-05 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9732
# Epoch 52/120
# 528/528 [==============================] - 6s 11ms/step - loss: 1.0792e-05 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9732
# Epoch 53/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.0201e-05 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9732
# Epoch 54/120
# 528/528 [==============================] - 5s 10ms/step - loss: 9.6684e-06 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9732
# Epoch 55/120
# 528/528 [==============================] - 5s 10ms/step - loss: 9.1862e-06 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9732
# Epoch 56/120
# 528/528 [==============================] - 5s 9ms/step - loss: 8.7463e-06 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 0.9732
# Epoch 57/120
# 528/528 [==============================] - 6s 11ms/step - loss: 8.3459e-06 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9732
# Epoch 58/120
# 528/528 [==============================] - 5s 9ms/step - loss: 7.9763e-06 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9732
# Epoch 59/120
# 528/528 [==============================] - 5s 10ms/step - loss: 7.6380e-06 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9732
# Epoch 60/120
# 528/528 [==============================] - 5s 10ms/step - loss: 7.3254e-06 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9732
# Epoch 61/120
# 528/528 [==============================] - 5s 9ms/step - loss: 7.0356e-06 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9732
# Epoch 62/120
# 528/528 [==============================] - 6s 11ms/step - loss: 6.7671e-06 - accuracy: 1.0000 - val_loss: 0.1918 - val_accuracy: 0.9732
# Epoch 63/120
# 528/528 [==============================] - 5s 9ms/step - loss: 6.5162e-06 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9732
# Epoch 64/120
# 528/528 [==============================] - 5s 9ms/step - loss: 6.2830e-06 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9732
# Epoch 65/120
# 528/528 [==============================] - 6s 11ms/step - loss: 6.0645e-06 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9737
# Epoch 66/120
# 528/528 [==============================] - 5s 9ms/step - loss: 5.8599e-06 - accuracy: 1.0000 - val_loss: 0.1937 - val_accuracy: 0.9737
# Epoch 67/120
# 528/528 [==============================] - 6s 11ms/step - loss: 5.6680e-06 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9737
# Epoch 68/120
# 528/528 [==============================] - 5s 9ms/step - loss: 5.4875e-06 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9737
# Epoch 69/120
# 528/528 [==============================] - 5s 9ms/step - loss: 5.3176e-06 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9741
# Epoch 70/120
# 528/528 [==============================] - 6s 11ms/step - loss: 5.1573e-06 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9741
# Epoch 71/120
# 528/528 [==============================] - 5s 10ms/step - loss: 5.0057e-06 - accuracy: 1.0000 - val_loss: 0.1957 - val_accuracy: 0.9741
# Epoch 72/120
# 528/528 [==============================] - 6s 12ms/step - loss: 4.8625e-06 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9741
# Epoch 73/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.7269e-06 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9741
# Epoch 74/120
# 528/528 [==============================] - 5s 10ms/step - loss: 4.5981e-06 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9741
# Epoch 75/120
# 528/528 [==============================] - 6s 11ms/step - loss: 4.4757e-06 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9741
# Epoch 76/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.3591e-06 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9741
# Epoch 77/120
# 528/528 [==============================] - 6s 11ms/step - loss: 4.2482e-06 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9741
# Epoch 78/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.1422e-06 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9741
# Epoch 79/120
# 528/528 [==============================] - 5s 9ms/step - loss: 4.0415e-06 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9741
# Epoch 80/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.9448e-06 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9741
# Epoch 81/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.8527e-06 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9741
# Epoch 82/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.7645e-06 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9741
# Epoch 83/120
# 528/528 [==============================] - 5s 10ms/step - loss: 3.6799e-06 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9741
# Epoch 84/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.5989e-06 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9741
# Epoch 85/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.5211e-06 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9741
# Epoch 86/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.4466e-06 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9741
# Epoch 87/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.3746e-06 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9741
# Epoch 88/120
# 528/528 [==============================] - 5s 10ms/step - loss: 3.3056e-06 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9741
# Epoch 89/120
# 528/528 [==============================] - 5s 9ms/step - loss: 3.2390e-06 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9741
# Epoch 90/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.1750e-06 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.9741
# Epoch 91/120
# 528/528 [==============================] - 5s 10ms/step - loss: 3.1133e-06 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.9741
# Epoch 92/120
# 528/528 [==============================] - 6s 11ms/step - loss: 3.0538e-06 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9741
# Epoch 93/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.9965e-06 - accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9741
# Epoch 94/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.9412e-06 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9741
# Epoch 95/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.8876e-06 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9741
# Epoch 96/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.8359e-06 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.9741
# Epoch 97/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.7860e-06 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9741
# Epoch 98/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.7377e-06 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9741
# Epoch 99/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.6908e-06 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9741
# Epoch 100/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.6454e-06 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9737
# Epoch 101/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.6016e-06 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9737
# Epoch 102/120
# 528/528 [==============================] - 5s 10ms/step - loss: 2.5589e-06 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9737
# Epoch 103/120
# 528/528 [==============================] - 6s 10ms/step - loss: 2.5178e-06 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9737
# Epoch 104/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.4775e-06 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9737
# Epoch 105/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.4387e-06 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9737
# Epoch 106/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.4007e-06 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9737
# Epoch 107/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.3641e-06 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9737
# Epoch 108/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.3284e-06 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9737
# Epoch 109/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.2937e-06 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9737
# Epoch 110/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.2599e-06 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9737
# Epoch 111/120
# 528/528 [==============================] - 6s 12ms/step - loss: 2.2272e-06 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9737
# Epoch 112/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.1952e-06 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9737
# Epoch 113/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.1641e-06 - accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9737
# Epoch 114/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.1339e-06 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9737
# Epoch 115/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.1044e-06 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9737
# Epoch 116/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.0755e-06 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9737
# Epoch 117/120
# 528/528 [==============================] - 5s 9ms/step - loss: 2.0476e-06 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9737
# Epoch 118/120
# 528/528 [==============================] - 6s 11ms/step - loss: 2.0203e-06 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9737
# Epoch 119/120
# 528/528 [==============================] - 5s 9ms/step - loss: 1.9936e-06 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9737
# Epoch 120/120
# 528/528 [==============================] - 6s 11ms/step - loss: 1.9676e-06 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9737

# %%
model.save("/content/gdrive/MyDrive/Models/WithAttentionWithoutDense.h5")
print("Model Score: \n")
score = model.evaluate(X_test, y_test)
print(score)
# Out:
# Model Score:
#
# 66/66 [==============================] - 0s 4ms/step - loss: 0.1787 - accuracy: 0.9829
# [0.1787218302488327, 0.9829303026199341]

# %% [markdown]
# ##METRICS

# %%
pip install plot_keras_history
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plot_keras_history
#   Downloading plot_keras_history-1.1.38.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (3.5.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from plot_keras_history) (1.7.3)
# Collecting support_developer>=1.0.2
#   Downloading support_developer-1.0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sanitize_ml_labels>=1.0.48
#   Downloading sanitize_ml_labels-1.0.50.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 KB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting compress_json
#   Downloading compress_json-1.0.8.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from matplotlib->plot_keras_history) (1.22.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->plot_keras_history) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.15.0)
# Building wheels for collected packages: plot_keras_history, sanitize_ml_labels, support_developer, compress_json
#   Building wheel for plot_keras_history (setup.py) ... done
#   Created wheel for plot_keras_history: filename=plot_keras_history-1.1.38-py3-none-any.whl size=9472 sha256=cfd1213321d76b581b4484ab86aca66e06e9f2bac9559f238993ad1741080f28
#   Stored in directory: /root/.cache/pip/wheels/97/a5/76/35ae3e15da1ce4530de8591b0bcd7716f6d6752a4808f01c04
#   Building wheel for sanitize_ml_labels (setup.py) ... done
#   Created wheel for sanitize_ml_labels: filename=sanitize_ml_labels-1.0.50-py3-none-any.whl size=320514 sha256=c46e0b7dfe3e93241aca9704d5200845d0e4c7df3b876e3a9c7eecfca585caef
#   Stored in directory: /root/.cache/pip/wheels/a3/5f/ba/ddd191edb6c749a63cffabd28714d5600b5b58014daf7434a8
#   Building wheel for support_developer (setup.py) ... done
#   Created wheel for support_developer: filename=support_developer-1.0.5-py3-none-any.whl size=5650 sha256=395f659a1cbcb054dce105a3585cb7dd222465942eabbd5e667eff76dd31d445
#   Stored in directory: /root/.cache/pip/wheels/11/5e/63/51e84640e77a7dc5f1e5f5eb597e8f1bc730a2818ee5c3fc03
#   Building wheel for compress_json (setup.py) ... done
#   Created wheel for compress_json: filename=compress_json-1.0.8-py3-none-any.whl size=4733 sha256=68501abe1df7d77ed4286e4faa80c8ca52ea8d433093a23c25b9e152a2d0ee47
#   Stored in directory: /root/.cache/pip/wheels/fe/36/4b/69aaa23fc0ea813dc1f8cca3372bff314abed354cac20a1cb9
# Successfully built plot_keras_history sanitize_ml_labels support_developer compress_json
# Installing collected packages: support_developer, compress_json, sanitize_ml_labels, plot_keras_history
# Successfully installed compress_json-1.0.8 plot_keras_history-1.1.38 sanitize_ml_labels-1.0.50 support_developer-1.0.5

# %%
from plot_keras_history import show_history, plot_history
plot_history(history)
# Out:
# (<Figure size 1000x500 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Loss'}, xlabel='Epochs', ylabel='Loss'>,
#         <AxesSubplot:title={'center':'Accuracy'}, xlabel='Epochs', ylabel='Accuracy'>],
#        dtype=object))

# %%
import matplotlib.pyplot as plt
import itertools
import numpy as np

def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
print("Model Classification Report: \n")
y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
print(classification_report(np.argmax(y_test, axis=1), y_pred))
plot_confusion_matrix(cm, classes=["Does not have Wake Word", "Has Wake Word"])
# Out:
# Model Classification Report:
#
# 66/66 [==============================] - 4s 34ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1049
#            1       0.98      0.98      0.98      1060
#
#     accuracy                           0.98      2109
#    macro avg       0.98      0.98      0.98      2109
# weighted avg       0.98      0.98      0.98      2109
#
# Confusion matrix, without normalization
# [[1032   17]
#  [  19 1041]]

# %% [markdown]
# ##PREDICTION & LATENCY

# %%
pip install spafe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spafe
#   Downloading spafe-0.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from spafe) (4.5.0)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.7.3)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.8/dist-packages (from spafe) (1.22.4)
# Installing collected packages: spafe
# Successfully installed spafe-0.3.1

# %%
import spafe
from spafe.features.lfcc import lfcc
import pywt

# %%
def predict(audio):
  audio_data, sr = librosa.load(audio)

  wavelet = 'db4'
  level = 4
  coeffs = pywt.wavedec(audio_data, wavelet, level=level)
  threshold = np.median(np.abs(coeffs[-level])) / 0.6745
  for i in range(1, len(coeffs)):
    coeffs[i] = pywt.threshold(coeffs[i], threshold)
  denoised_audio = pywt.waverec(coeffs, wavelet)

  lfccs  = lfcc(denoised_audio, fs = sr, num_ceps=13)
  lfccs_processed = np.mean(lfccs.T, axis=0) # some pre-processing
  lfccs_new = np.expand_dims(np.asarray(lfccs_processed), axis=0)
  predictions = model.predict(lfccs_new)
  return predictions

# %%
audio_for_pred = "/content/gdrive/MyDrive/Marvin/marvin (170).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# [[0. 1.]]

# %%
audio_for_pred = "/content/gdrive/MyDrive/False/yes (824).wav"
print(np.round(predict(audio_for_pred)))
# Out:
# 1/1 [==============================] - 0s 154ms/step
# [[1. 0.]]
